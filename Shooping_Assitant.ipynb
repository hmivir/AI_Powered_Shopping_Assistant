# %%
import importlib
import src.tools

importlib.reload(src.tools)
from src.tools import search_products

print(search_products("healthy snacks"))
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# d:\2_Anyone_ML\Agent_Specialization\AI_Powered_Shopping_Assistant\venv\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Usuario\.cache\huggingface\hub\models--mixedbread-ai--mxbai-embed-large-v1. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
# ...

# %%
import importlib
import src.tools

importlib.reload(src.tools)  # recarga el módulo con los cambios recientes

from src.tools import search_tool
result = search_tool.invoke("healthy snacks")
print(result)
# Out:
# - Heart Healthy Mix (ID: 26148)
#   Aisle: nuts seeds dried fruit
#   Department: snacks
#   Details: Heart Healthy Mix, found in the nuts seeds dried fruit aisle of the snacks department.
#
# - Healthy Grains with Chia Seeds, Raspberry Clusters (ID: 28202)
#   Aisle: energy granola bars
#   Department: snacks
#   Details: Healthy Grains with Chia Seeds, Raspberry Clusters, found in the energy granola bars aisle of the snacks department.
#
# - NUTrition Wholesome Nut Mix (ID: 21756)
#   Aisle: nuts seeds dried fruit
#   Department: snacks
#   Details: NUTrition Wholesome Nut Mix, found in the nuts seeds dried fruit aisle of the snacks department.
#
# - Organic High Antioxidant Trail Mix (ID: 34471)
#   Aisle: trail mix snack mix
#   Department: snacks
#   Details: Organic High Antioxidant Trail Mix, found in the trail mix snack mix aisle of the snacks department.
#
# - Mango Coconut Chia Squeeze Vitality Snack (ID: 3663)
#   Aisle: nuts seeds dried fruit
#   Department: snacks
# ...

# %%
# 1. Buscar productos que contengan "peanut" en pantry
import importlib
import src.tools
from src.tools import structured_search_tool

importlib.reload(src.tools)
# Out:
# <module 'src.tools' from 'd:\\2_Anyone_ML\\Agent_Specialization\\AI_Powered_Shopping_Assistant\\src\\tools.py'>

# %%
results = structured_search_tool.invoke({
    "product_name": "peanut",
})
print(results)
# Out:
# [{'product_id': 34, 'product_name': 'Peanut Butter Cereal', 'aisle_id': 121, 'department_id': 14, 'Unnamed: 4': nan, 'Unnamed: 5': nan, 'Unnamed: 6': nan, 'price': 3.49, 'aisle': 'cereal', 'department': 'breakfast'}, {'product_id': 100, 'product_name': 'Peanut Butter & Strawberry Jam Sandwich', 'aisle_id': 38, 'department_id': 1, 'Unnamed: 4': nan, 'Unnamed: 5': nan, 'Unnamed: 6': nan, 'price': 3.49, 'aisle': 'frozen meals', 'department': 'frozen'}, {'product_id': 164, 'product_name': 'Peanut Butter Cacao Quinoa Clusters', 'aisle_id': 3, 'department_id': 19, 'Unnamed: 4': nan, 'Unnamed: 5': nan, 'Unnamed: 6': nan, 'price': 4.99, 'aisle': 'energy granola bars', 'department': 'snacks'}, {'product_id': 594, 'product_name': 'Gluten Free Peanut Butter Berry  Chewy With A Crunch Granola Bars', 'aisle_id': 3, 'department_id': 19, 'Unnamed: 4': nan, 'Unnamed: 5': nan, 'Unnamed: 6': nan, 'price': 3.49, 'aisle': 'energy granola bars', 'department': 'snacks'}, {'product_id': 619, 'product_name'
# ...

# %%
from google.generativeai import list_models
import google.generativeai as genai

genai.configure(api_key="AIzaSyCvshpxRtY-Id2G-557gY9vAegxOGTCSFg")

for m in list_models():
    print(m.name, "→", m.supported_generation_methods)
# Out:
# models/embedding-gecko-001 → ['embedText', 'countTextTokens']
# models/gemini-1.0-pro-vision-latest → ['generateContent', 'countTokens']
# models/gemini-pro-vision → ['generateContent', 'countTokens']
# models/gemini-1.5-pro-latest → ['generateContent', 'countTokens']
# models/gemini-1.5-pro-002 → ['generateContent', 'countTokens', 'createCachedContent']
# models/gemini-1.5-pro → ['generateContent', 'countTokens']
# models/gemini-1.5-flash-latest → ['generateContent', 'countTokens']
# models/gemini-1.5-flash → ['generateContent', 'countTokens']
# models/gemini-1.5-flash-002 → ['generateContent', 'countTokens', 'createCachedContent']
# models/gemini-1.5-flash-8b → ['createCachedContent', 'generateContent', 'countTokens']
# models/gemini-1.5-flash-8b-001 → ['createCachedContent', 'generateContent', 'countTokens']
# models/gemini-1.5-flash-8b-latest → ['createCachedContent', 'generateContent', 'countTokens']
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-pro-latest",
    google_api_key="AIzaSyCvshpxRtY-Id2G-557gY9vAegxOGTCSFg"
)

response = llm.invoke("Tell me 3 AI applications in healthcare.")
print(response.content)
# Out:
# 1. **Medical Imaging Diagnosis:** AI algorithms, particularly deep learning models, are being trained to analyze medical images like X-rays, CT scans, and MRIs. They can help detect anomalies like tumors, fractures, and other diseases often faster and with greater accuracy than humans, aiding radiologists in making diagnoses and prioritizing urgent cases.
#
# 2. **Drug Discovery and Development:** AI is accelerating the process of discovering and developing new drugs. It can analyze vast datasets of molecular information to identify potential drug candidates, predict their efficacy and side effects, and optimize clinical trial design. This can significantly reduce the time and cost associated with bringing new treatments to market.
#
# ...
